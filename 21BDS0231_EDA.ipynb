# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalreddy9514/EDA/blob/main/21BDS0231_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NAME: VISHAL REDDY BUSANAGARI
# # REG.NO: 21BDS0231

# %%
# !git clone https://github.com/vishalreddy9514/EDA.git
# Out:
# Cloning into 'EDA'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# Receiving objects: 100% (6/6), 49.42 KiB | 6.18 MiB/s, done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)

# %% [markdown]
# # Module 1

# %%
import pandas as pd

df = pd.read_csv("EDA/bcancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 1. Loading the Dataset
file_path = "https://raw.githubusercontent.com/vishalreddy9514/EDA/main/bcancer.csv"
df = pd.read_csv(file_path)
print("First 5 rows of the dataset:")
print(df.head())

# 2. Summary Statistics for Numerical and Categorical Data
print("\nSummary statistics for numerical data:")
print(df.describe())

# Checking for categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
print("\nCategorical Columns:")
print(categorical_cols)

if len(categorical_cols) > 0:
    print("\nSummary for categorical columns:")
    print(df[categorical_cols].describe())

# 3. Data Cleaning (Handling Missing Values)
print("\nMissing values in the dataset:")
print(df.isnull().sum())

# Dropping rows with missing data
df_cleaned = df.dropna()
print("\nData after dropping missing values:")
print(df_cleaned.head())

# Filling missing data using forward fill
df_filled = df.fillna(method='ffill')
print("\nData after forward fill:")
print(df_filled.head())

# 4. Visualization
# Histogram for a key numerical feature (radius_mean)
plt.figure(figsize=(8, 6))
df['radius_mean'].hist(bins=20)
plt.title('Histogram of Radius Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Frequency')
plt.show()

# Bar plot for categorical variable (Diagnosis)
if 'diagnosis' in df.columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(x='diagnosis', data=df)
    plt.title('Distribution of Diagnosis')
    plt.xlabel('Diagnosis (B = Benign, M = Malignant)')
    plt.ylabel('Count')
    plt.show()

# 5. Measurement Scales (Nominal, Ordinal, Interval, Ratio)
# Nominal: Diagnosis
print("\nValue counts for 'diagnosis' column (Nominal scale example):")
print(df['diagnosis'].value_counts())

# Ordinal: Creating a risk rank based on radius_mean
df['risk_rank'] = pd.qcut(df['radius_mean'], 5, labels=['very low', 'low', 'medium', 'high', 'very high'])
print("\nFirst 5 rows with 'risk_rank' (Ordinal scale example):")
print(df[['radius_mean', 'risk_rank']].head())

# 6. Classical Analysis (T-test for radius_mean)
t_stat, p_value = stats.ttest_1samp(df['radius_mean'].dropna(), popmean=14)
print(f"\nT-test: t-stat = {t_stat}, p-value = {p_value}")


# 7. Software Tools for EDA
print("\nSoftware Tools for EDA:")
print("Python: Pandas, Seaborn, Matplotlib")
print("R: GGPlot2, dplyr, tidyr")
print("Excel/Tableau: For basic EDA tasks")
# Out:
# First 5 rows of the dataset:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Module 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import KBinsDiscretizer
import seaborn as sns
from scipy import stats

# 1. Loading the Dataset
file_path = "https://raw.githubusercontent.com/vishalreddy9514/EDA/main/bcancer.csv"
df = pd.read_csv(file_path)
print("First 5 rows of the dataset:")
print(df.head())

# 2. Data Deduplication
print("\nShape before deduplication:", df.shape)
df_deduped = df.drop_duplicates()
print("Shape after deduplication:", df_deduped.shape)

# 3. Replacing Values
# Replace specific values in a column (Example: replacing zeros with NaN in radius_mean)
df_replaced = df.copy()
df_replaced['radius_mean'] = df_replaced['radius_mean'].replace(0, np.nan)
print("\nRadius_mean column after replacing 0 with NaN:")
print(df_replaced[['radius_mean']].head())

# Replace NaN values with a specific value (mean of the column)
df_replaced.fillna(value={'radius_mean': df_replaced['radius_mean'].mean()}, inplace=True)
print("\nRadius_mean column after replacing NaN with mean value:")
print(df_replaced[['radius_mean']].head())

# 4. Discretization and Binning
# Bin 'radius_mean' column into categories
df_binned = df.copy()
df_binned['radius_mean_binned'] = pd.cut(df_binned['radius_mean'].fillna(df_binned['radius_mean'].mean()), bins=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])
print("\nBinned 'radius_mean' column:")
print(df_binned[['radius_mean', 'radius_mean_binned']].head())

# 5. Handling Missing Data - Traditional Method (Maximum Likelihood Estimation)
# Introduce some missing values for demonstration
df_with_na = df.copy()
df_with_na.loc[10:15, 'radius_mean'] = np.nan  # Creating missing values in 'radius_mean'

# Handle missing data using SimpleImputer (Maximum Likelihood Estimation approximated via mean substitution here)
imputer = SimpleImputer(strategy='mean')
df_with_na['radius_mean'] = imputer.fit_transform(df_with_na[['radius_mean']])
print("\nRadius_mean column after imputing missing values using MLE approximation (mean):")
print(df_with_na[['radius_mean']].head(20))

# 6. Discretization with KBinsDiscretizer
kbins = KBinsDiscretizer(n_bins=4, encode='ordinal', strategy='uniform')
df['radius_mean_binned_kbins'] = kbins.fit_transform(df[['radius_mean']].fillna(df['radius_mean'].mean()))
print("\nDiscretized 'radius_mean' column using KBinsDiscretizer:")
print(df[['radius_mean', 'radius_mean_binned_kbins']].head())

# 7. Visualizing Binned Data
plt.figure(figsize=(10, 6))
df_binned['radius_mean_binned'].value_counts().plot(kind='bar')
plt.title('Distribution of Radius Mean Bins')
plt.xlabel('Radius Mean Bins')
plt.ylabel('Frequency')
plt.show()
# Out:
# First 5 rows of the dataset:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # MODULE 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
file_path = "https://raw.githubusercontent.com/vishalreddy9514/EDA/main/bcancer.csv"
df = pd.read_csv(file_path)

# 1. Univariate Analysis
print("Univariate Analysis (Summary Statistics):")
print(df.describe())

# Visualizing Univariate Data (Histograms for Numerical Features)
plt.figure(figsize=(10, 6))
df['radius_mean'].hist(bins=20)
plt.title('Histogram of Radius Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Frequency')
plt.show()

# 2. Bivariate Analysis
print("\nBivariate Analysis (Correlation Matrix):")
# Select only relevant numerical columns for correlation calculation
selected_features = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean']
correlation_matrix = df[selected_features].corr()
print(correlation_matrix)

# Heatmap of Correlation Matrix (Using Selected Features for Readability)
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap (Selected Features)')
plt.show()

# Scatter Plot for Bivariate Analysis
plt.figure(figsize=(8, 6))
sns.scatterplot(x='radius_mean', y='compactness_mean', data=df)
plt.title('Scatter Plot of Radius Mean vs Compactness Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Compactness Mean')
plt.show()

# 3. Multivariate Analysis
print("\nMultivariate Analysis (Pairplot with Selected Features):")
sns.pairplot(df[['radius_mean', 'texture_mean', 'smoothness_mean', 'compactness_mean']])
plt.show()
# Out:
# Univariate Analysis (Summary Statistics):
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...
